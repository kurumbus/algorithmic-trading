# %% [markdown]
# ## V3
# model with 72 lags instead of 24

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# ### DATA

# %%
symbol = "EURUSD=X"
start = "2022-08-27"
end = "2024-08-20"
interval = '1h'

# %% [markdown]
# ### Variables

# %%
sma_short =20
sma_long=50

# %% [markdown]
# ## Downloading Data

# %%
df = yf.download(symbol, start, end, interval=interval)
#df.rename(columns={"Close": "price"}, inplace=True)
df.drop(columns=['Adj Close', 'Volume'], inplace=True)
df.index = df.index.tz_convert('utc')
df['returns'] = np.log(df['Close'].div(df['Close'].shift(1)))
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                Open      High       Low     Close   returns
# Datetime
# 2022-08-28 23:00:00+00:00  0.995520  0.995520  0.993838  0.993838       NaN
# 2022-08-29 00:00:00+00:00  0.994233  0.995124  0.993246  0.993345 -0.000497
# 2022-08-29 01:00:00+00:00  0.993345  0.993937  0.992162  0.993443  0.000099
# 2022-08-29 02:00:00+00:00  0.993147  0.993937  0.992753  0.993049 -0.000397
# 2022-08-29 03:00:00+00:00  0.992950  0.993345  0.992457  0.992654 -0.000397
# ...                             ...       ...       ...       ...       ...
# 2024-08-19 18:00:00+00:00  1.108156  1.108770  1.108033  1.108525  0.000554
# 2024-08-19 19:00:00+00:00  1.108402  1.108893  1.108279  1.108647  0.000111
# 2024-08-19 20:00:00+00:00  1.108647  1.108893  1.108525  1.108893  0.000222
# 2024-08-19 21:00:00+00:00  1.108525  1.109139  1.108279  1.108647 -0.000222
# 2024-08-19 22:00:00+00:00  1.109016  1.109016  1.108647  1.108770  0.000111
#
# [12247 rows x 5 columns]

# %%
df['day_of_week'] = df.index.dayofweek

# %%
df.Close.plot()
plt.show()

# %%
snp = yf.download('^SPX', start, end, interval=interval)
snp.index = snp.index.tz_convert('utc')
snp.index = snp.index.ceil('h')
snp['snp_volatility'] = (snp['High'] -snp['Low']) / (snp['Open']+snp['Close']+snp['Low']+snp['High'])  *  4 ## not ideal because previous day might close lower or higher
snp['snp_returns'] = np.log(snp['Close'].div(snp['Close'].shift(1)))
snp.rename(columns={"Close": "snp_price", 'Volume': 'snp_volume' }, inplace=True)
snp.drop(columns=['Adj Close', 'Open', 'High', 'Low'], inplace=True)
snp
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                              snp_price  snp_volume  snp_volatility  \
# Datetime
# 2022-08-29 14:00:00+00:00  4040.330078           0        0.006902
# 2022-08-29 15:00:00+00:00  4027.120117   238991365        0.006495
# 2022-08-29 16:00:00+00:00  4043.340088   183154616        0.006174
# 2022-08-29 17:00:00+00:00  4049.459961   169493518        0.005165
# 2022-08-29 18:00:00+00:00  4045.560059   163613948        0.004866
# ...                                ...         ...             ...
# 2024-08-19 16:00:00+00:00  5579.950195   191317840        0.001935
# 2024-08-19 17:00:00+00:00  5583.229980   160907370        0.001672
# 2024-08-19 18:00:00+00:00  5588.919922   173170955        0.001423
# 2024-08-19 19:00:00+00:00  5594.100098   215252315        0.001372
# 2024-08-19 20:00:00+00:00  5607.520020   242772673        0.002894
#
#                            snp_returns
# Datetime
# 2022-08-29 14:00:00+00:00          NaN
# 2022-08-29 15:00:00+00:00    -0.003275
# 2022-08-29 16:00:00+00:00     0.004020
# 2022-08-29 17:00:00+00:00     0.001512
# 2022-08-29 18:00:00+00:00    -0.000964
# ...                                ...
# 2024-08-19 16:00:00+00:00     0.000610
# 2024-08-19 17:00:00+00:00     0.000588
# 2024-08-19 18:00:00+00:00     0.001019
# 2024-08-19 19:00:00+00:00     0.000926
# 2024-08-19 20:00:00+00:00     0.002396
#
# [3456 rows x 4 columns]

# %%
forex_combined = snp.join(df, how='outer')
forex_combined
# Out:
#                              snp_price   snp_volume  snp_volatility  \
# Datetime
# 2022-08-28 23:00:00+00:00          NaN          NaN             NaN
# 2022-08-29 00:00:00+00:00          NaN          NaN             NaN
# 2022-08-29 01:00:00+00:00          NaN          NaN             NaN
# 2022-08-29 02:00:00+00:00          NaN          NaN             NaN
# 2022-08-29 03:00:00+00:00          NaN          NaN             NaN
# ...                                ...          ...             ...
# 2024-08-19 18:00:00+00:00  5588.919922  173170955.0        0.001423
# 2024-08-19 19:00:00+00:00  5594.100098  215252315.0        0.001372
# 2024-08-19 20:00:00+00:00  5607.520020  242772673.0        0.002894
# 2024-08-19 21:00:00+00:00          NaN          NaN             NaN
# 2024-08-19 22:00:00+00:00          NaN          NaN             NaN
#
#                            snp_returns      Open      High       Low  \
# Datetime
# 2022-08-28 23:00:00+00:00          NaN  0.995520  0.995520  0.993838
# 2022-08-29 00:00:00+00:00          NaN  0.994233  0.995124  0.993246
# 2022-08-29 01:00:00+00:00          NaN  0.993345  0.993937  0.992162
# 2022-08-29 02:00:00+00:00          NaN  0.993147  0.993937  0.992753
# 2022-08-29 03:00:00+00:00          NaN  0.992950  0.993345  0.992457
# ...                                ...       ...       ...       ...
# 2024-08-19 18:00:00+00:00     0.001019  1.108156  1.108770  1.108033
# 2024-08-19 19:00:00+00:00     0.000926  1.108402  1.108893  1.108279
# 2024-08-19 20:00:00+00:00     0.002396  1.108647  1.108893  1.108525
# 2024-08-19 21:00:00+00:00          NaN  1.108525  1.109139  1.108279
# 2024-08-19 22:00:00+00:00          NaN  1.109016  1.109016  1.108647
#
#                               Close   returns  day_of_week
# Datetime
# 2022-08-28 23:00:00+00:00  0.993838       NaN            6
# 2022-08-29 00:00:00+00:00  0.993345 -0.000497            0
# 2022-08-29 01:00:00+00:00  0.993443  0.000099            0
# 2022-08-29 02:00:00+00:00  0.993049 -0.000397            0
# 2022-08-29 03:00:00+00:00  0.992654 -0.000397            0
# ...                             ...       ...          ...
# 2024-08-19 18:00:00+00:00  1.108525  0.000554            0
# 2024-08-19 19:00:00+00:00  1.108647  0.000111            0
# 2024-08-19 20:00:00+00:00  1.108893  0.000222            0
# 2024-08-19 21:00:00+00:00  1.108647 -0.000222            0
# 2024-08-19 22:00:00+00:00  1.108770  0.000111            0
#
# [12247 rows x 10 columns]

# %%
gold_ticker = 'GC=F'
# Fetch historical data
gold_data = yf.download(gold_ticker, start=start, end=end,  interval=interval)
gold_data.index = gold_data.index.tz_convert('utc')
gold_data.rename(columns={"Close": "gold_price", 'Volume': 'gold_volume' }, inplace=True)
gold_data.drop(columns=['Adj Close', 'Open', 'High', 'Low'], inplace=True)
gold_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                             gold_price  gold_volume
# Datetime
# 2022-08-28 22:00:00+00:00  1747.099976         2303
# 2022-08-28 23:00:00+00:00  1746.199951         3175
# 2022-08-29 00:00:00+00:00  1745.800049         3193
# 2022-08-29 01:00:00+00:00  1735.500000         9299
# 2022-08-29 02:00:00+00:00  1737.900024         4304
# ...                                ...          ...
# 2024-08-19 23:00:00+00:00  2541.800049         1335
# 2024-08-20 00:00:00+00:00  2543.000000         2746
# 2024-08-20 01:00:00+00:00  2540.000000         5307
# 2024-08-20 02:00:00+00:00  2537.399902         4353
# 2024-08-20 03:00:00+00:00  2539.399902         2002
#
# [11348 rows x 2 columns]

# %%
forex_combined = gold_data.join(forex_combined, how='outer')

# %%
ffill_columns = ['gold_price', 'gold_volume', 'snp_returns', 'snp_volume', 'snp_price', 'snp_volatility']
forex_combined[ffill_columns] = forex_combined[ffill_columns].ffill()
forex_combined['dir'] = np.where(forex_combined['returns'] > 0, 1,0)
forex_combined
# Out:
#                             gold_price  gold_volume   snp_price   snp_volume  \
# Datetime
# 2022-08-28 22:00:00+00:00  1747.099976       2303.0         NaN          NaN
# 2022-08-28 23:00:00+00:00  1746.199951       3175.0         NaN          NaN
# 2022-08-29 00:00:00+00:00  1745.800049       3193.0         NaN          NaN
# 2022-08-29 01:00:00+00:00  1735.500000       9299.0         NaN          NaN
# 2022-08-29 02:00:00+00:00  1737.900024       4304.0         NaN          NaN
# ...                                ...          ...         ...          ...
# 2024-08-19 23:00:00+00:00  2541.800049       1335.0  5607.52002  242772673.0
# 2024-08-20 00:00:00+00:00  2543.000000       2746.0  5607.52002  242772673.0
# 2024-08-20 01:00:00+00:00  2540.000000       5307.0  5607.52002  242772673.0
# 2024-08-20 02:00:00+00:00  2537.399902       4353.0  5607.52002  242772673.0
# 2024-08-20 03:00:00+00:00  2539.399902       2002.0  5607.52002  242772673.0
#
#                            snp_volatility  snp_returns      Open      High  \
# Datetime
# 2022-08-28 22:00:00+00:00             NaN          NaN       NaN       NaN
# 2022-08-28 23:00:00+00:00             NaN          NaN  0.995520  0.995520
# 2022-08-29 00:00:00+00:00             NaN          NaN  0.994233  0.995124
# 2022-08-29 01:00:00+00:00             NaN          NaN  0.993345  0.993937
# 2022-08-29 02:00:00+00:00             NaN          NaN  0.993147  0.993937
# ...                                   ...          ...       ...       ...
# 2024-08-19 23:00:00+00:00        0.002894     0.002396       NaN       NaN
# 2024-08-20 00:00:00+00:00        0.002894     0.002396       NaN       NaN
# 2024-08-20 01:00:00+00:00        0.002894     0.002396       NaN       NaN
# 2024-08-20 02:00:00+00:00        0.002894     0.002396       NaN       NaN
# 2024-08-20 03:00:00+00:00        0.002894     0.002396       NaN       NaN
#
#                                 Low     Close   returns  day_of_week  dir
# Datetime
# 2022-08-28 22:00:00+00:00       NaN       NaN       NaN          NaN    0
# 2022-08-28 23:00:00+00:00  0.993838  0.993838       NaN          6.0    0
# 2022-08-29 00:00:00+00:00  0.993246  0.993345 -0.000497          0.0    0
# 2022-08-29 01:00:00+00:00  0.992162  0.993443  0.000099          0.0    1
# 2022-08-29 02:00:00+00:00  0.992753  0.993049 -0.000397          0.0    0
# ...                             ...       ...       ...          ...  ...
# 2024-08-19 23:00:00+00:00       NaN       NaN       NaN          NaN    0
# 2024-08-20 00:00:00+00:00       NaN       NaN       NaN          NaN    0
# 2024-08-20 01:00:00+00:00       NaN       NaN       NaN          NaN    0
# 2024-08-20 02:00:00+00:00       NaN       NaN       NaN          NaN    0
# 2024-08-20 03:00:00+00:00       NaN       NaN       NaN          NaN    0
#
# [12375 rows x 13 columns]

# %%
forex_combined.dropna(inplace=True)

# %%
extra_features = ['Open', 'High', 'Low', 'Close', 'returns']
lags = 24
cols = []
features = ffill_columns + extra_features
features
# Out:
# ['gold_price',
#  'gold_volume',
#  'snp_returns',
#  'snp_volume',
#  'snp_price',
#  'snp_volatility',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'returns']

# %%
for f in features:
    for lag in range(1, lags + 1):
        col = "{}_lag_{}".format(f, lag)
        forex_combined[col] = forex_combined[f].shift(lag)
        cols.append(col)
forex_combined.dropna(inplace=True)
forex_combined
# Out:
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# ...
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
# C:\Users\grigo\AppData\Local\Temp\ipykernel_5576\1825698716.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   forex_combined[col] = forex_combined[f].shift(lag)
#                             gold_price  gold_volume    snp_price   snp_volume  \
# Datetime
# 2022-08-30 15:00:00+00:00  1737.800049      10693.0  3991.939941  303972709.0
# 2022-08-30 16:00:00+00:00  1735.800049       5181.0  3991.959961  197123531.0
# 2022-08-30 17:00:00+00:00  1735.800049       6423.0  3975.770020  186525504.0
# 2022-08-30 18:00:00+00:00  1735.699951       2296.0  3975.189941  193156989.0
# 2022-08-30 19:00:00+00:00  1734.900024       3164.0  3989.540039  224540573.0
# ...                                ...          ...          ...          ...
# 2024-08-19 18:00:00+00:00  2542.800049       5353.0  5588.919922  173170955.0
# 2024-08-19 19:00:00+00:00  2543.899902       3701.0  5594.100098  215252315.0
# 2024-08-19 20:00:00+00:00  2542.600098       1749.0  5607.520020  242772673.0
# 2024-08-19 21:00:00+00:00  2542.600098       1749.0  5607.520020  242772673.0
# 2024-08-19 22:00:00+00:00  2542.500000          0.0  5607.520020  242772673.0
#
#                            snp_volatility  snp_returns      Open      High  \
# Datetime
# 2022-08-30 15:00:00+00:00        0.009543    -0.003466  0.999400  1.003512
# 2022-08-30 16:00:00+00:00        0.004345     0.000005  1.002305  1.003512
# 2022-08-30 17:00:00+00:00        0.005411    -0.004064  1.002908  1.002908
# 2022-08-30 18:00:00+00:00        0.004888    -0.000146  1.002004  1.003210
# 2022-08-30 19:00:00+00:00        0.006125     0.003603  1.002406  1.003512
# ...                                   ...          ...       ...       ...
# 2024-08-19 18:00:00+00:00        0.001423     0.001019  1.108156  1.108770
# 2024-08-19 19:00:00+00:00        0.001372     0.000926  1.108402  1.108893
# 2024-08-19 20:00:00+00:00        0.002894     0.002396  1.108647  1.108893
# 2024-08-19 21:00:00+00:00        0.002894     0.002396  1.108525  1.109139
# 2024-08-19 22:00:00+00:00        0.002894     0.002396  1.109016  1.109016
#
#                                 Low     Close  ...  returns_lag_15  \
# Datetime                                       ...
# 2022-08-30 15:00:00+00:00  0.999400  1.002104  ...       -0.000400
# 2022-08-30 16:00:00+00:00  1.002004  1.002707  ...       -0.001600
# 2022-08-30 17:00:00+00:00  1.001402  1.002004  ...        0.000000
# 2022-08-30 18:00:00+00:00  1.001904  1.002406  ...        0.000800
# 2022-08-30 19:00:00+00:00  1.001803  1.002004  ...        0.000100
# ...                             ...       ...  ...             ...
# 2024-08-19 18:00:00+00:00  1.108033  1.108525  ...        0.000773
# 2024-08-19 19:00:00+00:00  1.108279  1.108647  ...        0.000000
# 2024-08-19 20:00:00+00:00  1.108525  1.108893  ...        0.000773
# 2024-08-19 21:00:00+00:00  1.108279  1.108647  ...       -0.000552
# 2024-08-19 22:00:00+00:00  1.108647  1.108770  ...        0.000110
#
#                            returns_lag_16  returns_lag_17  returns_lag_18  \
# Datetime
# 2022-08-30 15:00:00+00:00        0.001001        0.000000        0.000100
# 2022-08-30 16:00:00+00:00       -0.000400        0.001001        0.000000
# 2022-08-30 17:00:00+00:00       -0.001600       -0.000400        0.001001
# 2022-08-30 18:00:00+00:00        0.000000       -0.001600       -0.000400
# 2022-08-30 19:00:00+00:00        0.000800        0.000000       -0.001600
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00       -0.000110        0.000000        0.000662
# 2024-08-19 19:00:00+00:00        0.000773       -0.000110        0.000000
# 2024-08-19 20:00:00+00:00        0.000000        0.000773       -0.000110
# 2024-08-19 21:00:00+00:00        0.000773        0.000000        0.000773
# 2024-08-19 22:00:00+00:00       -0.000552        0.000773        0.000000
#
#                            returns_lag_19  returns_lag_20  returns_lag_21  \
# Datetime
# 2022-08-30 15:00:00+00:00        0.000200        0.000600       -0.001600
# 2022-08-30 16:00:00+00:00        0.000100        0.000200        0.000600
# 2022-08-30 17:00:00+00:00        0.000000        0.000100        0.000200
# 2022-08-30 18:00:00+00:00        0.001001        0.000000        0.000100
# 2022-08-30 19:00:00+00:00       -0.000400        0.001001        0.000000
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00       -0.000331        0.000110        0.000221
# 2024-08-19 19:00:00+00:00        0.000662       -0.000331        0.000110
# 2024-08-19 20:00:00+00:00        0.000000        0.000662       -0.000331
# 2024-08-19 21:00:00+00:00       -0.000110        0.000000        0.000662
# 2024-08-19 22:00:00+00:00        0.000773       -0.000110        0.000000
#
#                            returns_lag_22  returns_lag_23  returns_lag_24
# Datetime
# 2022-08-30 15:00:00+00:00       -0.000701        0.001801        0.001299
# 2022-08-30 16:00:00+00:00       -0.001600       -0.000701        0.001801
# 2022-08-30 17:00:00+00:00        0.000600       -0.001600       -0.000701
# 2022-08-30 18:00:00+00:00        0.000200        0.000600       -0.001600
# 2022-08-30 19:00:00+00:00        0.000100        0.000200        0.000600
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00        0.000331        0.000771        0.000771
# 2024-08-19 19:00:00+00:00        0.000221        0.000331        0.000771
# 2024-08-19 20:00:00+00:00        0.000110        0.000221        0.000331
# 2024-08-19 21:00:00+00:00       -0.000331        0.000110        0.000221
# 2024-08-19 22:00:00+00:00        0.000662       -0.000331        0.000110
#
# [12207 rows x 277 columns]

# %%
split = int(len(forex_combined)* 0.7)
train = forex_combined.iloc[:split].copy()
train
# Out:
#                             gold_price  gold_volume    snp_price   snp_volume  \
# Datetime
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00        0.000331        0.000771        0.000771
# 2024-08-19 19:00:00+00:00        0.000221        0.000331        0.000771
# 2024-08-19 20:00:00+00:00        0.000110        0.000221        0.000331
# 2024-08-19 21:00:00+00:00       -0.000331        0.000110        0.000221
# 2024-08-19 22:00:00+00:00        0.000662       -0.000331        0.000110
#
# [3663 rows x 277 columns]

# %%
mu, std = train.mean(), train.std()

# %%
train_standardized = (train-mu) / std

# %%
train_standardized
# Out:
#                            gold_price  gold_volume  snp_price  snp_volume  \
# Datetime
# 2022-08-30 15:00:00+00:00   -1.390359     0.377020  -0.680478    0.005995
# 2022-08-30 16:00:00+00:00   -1.407350    -0.266903  -0.680409   -0.894752
# 2022-08-30 17:00:00+00:00   -1.407350    -0.121810  -0.735621   -0.984094
# 2022-08-30 18:00:00+00:00   -1.408200    -0.603934  -0.737599   -0.928190
# 2022-08-30 19:00:00+00:00   -1.414996    -0.502532  -0.688662   -0.663624
# ...                               ...          ...        ...         ...
# 2024-01-16 19:00:00+00:00    1.115798    -0.289333   1.912170   -0.742633
# 2024-01-16 20:00:00+00:00    1.107303    -0.539215   1.927855   -0.512521
# 2024-01-16 21:00:00+00:00    1.106452    -0.872157   1.956434    0.278652
# 2024-01-16 22:00:00+00:00    1.106452    -0.872157   1.956434    0.278652
# 2024-01-16 23:00:00+00:00    1.103055    -0.474378   1.956434    0.278652
#
#                            snp_volatility  snp_returns      Open      High  \
# Datetime
# 2022-08-30 15:00:00+00:00        2.723099    -1.203663 -1.805296 -1.720132
# 2022-08-30 16:00:00+00:00        0.391589    -0.009288 -1.725986 -1.720132
# 2022-08-30 17:00:00+00:00        0.869719    -1.409390 -1.709517 -1.736682
# 2022-08-30 18:00:00+00:00        0.635038    -0.061222 -1.734210 -1.728408
# 2022-08-30 19:00:00+00:00        1.189899     1.228917 -1.723242 -1.720132
# ...                                   ...          ...       ...       ...
# 2024-01-16 19:00:00+00:00        0.381743    -1.013122  0.594868  0.589711
# 2024-01-16 20:00:00+00:00       -0.530956     0.321875  0.604557  0.592955
# 2024-01-16 21:00:00+00:00       -0.426632     0.594675  0.601325  0.596200
# 2024-01-16 22:00:00+00:00       -0.426632     0.594675  0.614249  0.599444
# 2024-01-16 23:00:00+00:00       -0.426632     0.594675  0.611017  0.599444
#
#                                 Low     Close  ...  returns_lag_15  \
# Datetime                                       ...
# 2022-08-30 15:00:00+00:00 -1.779931 -1.731903  ...       -0.352815
# 2022-08-30 16:00:00+00:00 -1.709102 -1.715443  ...       -1.383947
# 2022-08-30 17:00:00+00:00 -1.725482 -1.734644  ...       -0.008608
# 2022-08-30 18:00:00+00:00 -1.711833 -1.723674  ...        0.678824
# 2022-08-30 19:00:00+00:00 -1.714563 -1.734644  ...        0.077347
# ...                             ...       ...  ...             ...
# 2024-01-16 19:00:00+00:00  0.605115  0.604304  ...       -0.102523
# 2024-01-16 20:00:00+00:00  0.611545  0.601072  ...       -0.196281
# 2024-01-16 21:00:00+00:00  0.614762  0.607533  ...        0.272980
# 2024-01-16 22:00:00+00:00  0.621199  0.613997  ...       -0.102523
# 2024-01-16 23:00:00+00:00  0.627637  0.617230  ...       -1.040472
#
#                            returns_lag_16  returns_lag_17  returns_lag_18  \
# Datetime
# 2022-08-30 15:00:00+00:00        0
-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00    1.000000e+00
# min   -2.388574e+00 -8.721570e-01 -2.252687e+00 -2.556520e+00   -1.296278e+00
# 25%   -6.538043e-01 -5.919013e-01 -7.651186e-01 -4.081163e-01   -6.475696e-01
# 50%    3.274200e-01 -3.490285e-01 -1.827236e-01  7.146359e-03   -2.587220e-01
# 75%    7.190599e-01  1.521083e-01  8.410904e-01  3.241067e-01    3.892928e-01
# max    1.819222e+00  9.515998e+00  2.047486e+00  1.609350e+01    1.263305e+01
#
#         snp_returns          Open          High           Low         Close  \
# count  8.544000e+03  8.544000e+03  8.544000e+03  8.544000e+03  8.544000e+03
# mean  -2.328558e-17 -1.543501e-15 -2.355170e-15  2.428353e-15  2.860799e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.669546e+00 -3.024487e+00 -3.011762e+00 -3.012056e+00 -3.037459e+00
# 25%   -4.139266e-01 -2.548273e-01 -2.579295e-01 -2.509985e-01 -2.551464e-01
# 50%    1.767115e-02  2.282563e-01  2.276699e-01  2.305846e-01  2.279746e-01
# 75%    4.528527e-01  7.115255e-01  7.101979e-01  7.115824e-01  7.112811e-01
# max    1.401245e+01  1.651148e+00  1.685896e+00  1.646766e+00  1.654439e+00
#
#        ...  returns_lag_15  returns_lag_16  returns_lag_17  returns_lag_18  \
# count  ...    8.544000e+03    8.544000e+03    8.544000e+03    8.544000e+03
# mean   ...   -1.122697e-17   -8.316277e-19    2.079069e-18    2.494883e-18
# std    ...    1.000000e+00    1.000000e+00    1.000000e+00    1.000000e+00
# min    ...   -1.200014e+01   -1.200062e+01   -1.200063e+01   -1.200066e+01
# 25%    ...   -3.854174e-01   -3.856387e-01   -3.856499e-01   -3.856286e-01
# 50%    ...   -8.607894e-03   -8.829530e-03   -8.840528e-03   -8.817664e-03
# 75%    ...    3.723860e-01    3.723056e-01    3.722948e-01    3.723192e-01
# max    ...    1.500463e+01    1.500473e+01    1.500473e+01    1.500481e+01
#
#        returns_lag_19  returns_lag_20  returns_lag_21  returns_lag_22  \
# count    8.544000e+03    8.544000e+03    8.544000e+03    8.544000e+03
# mean     1.663255e-18   -6.237208e-19    4.989766e-18   -5.613487e-18
# std      1.000000e+00    1.000000e+00    1.000000e+00    1.000000e+00
# min     -1.200071e+01   -1.200061e+01   -1.199925e+01   -1.199901e+01
# 25%     -3.856709e-01   -3.857367e-01   -3.855880e-01   -3.855542e-01
# 50%     -8.859759e-03   -8.930964e-03   -8.813015e-03   -8.775341e-03
# 75%      3.722774e-01    3.726822e-01    3.727607e-01    3.727919e-01
# max      1.500478e+01    1.500449e+01    1.500305e+01    1.500284e+01
#
#        returns_lag_23  returns_lag_24
# count    8.544000e+03    8.544000e+03
# mean     4.158139e-19   -9.355812e-18
# std      1.000000e+00    1.000000e+00
# min     -1.199768e+01   -1.199994e+01
# 25%     -3.856230e-01   -3.860354e-01
# 50%     -8.889533e-03   -9.252614e-03
# 75%      3.726317e-01    3.727810e-01
# max      1.500091e+01    1.500292e+01
#
# [8 rows x 277 columns]

# %%
#cols.append('day_of_week')

# %%
import random
import numpy as np
import tensorflow as tf
from keras.api.layers import Dense, Dropout, LSTM
from keras.api.models import Sequential
from keras.api.regularizers import l1, l2
from keras.api.optimizers import Adam

def set_seeds(seed = 100):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
def cw(df):
    c0, c1 = np.bincount(df["dir"])
    w0 = (1/c0) * (len(df)) / 2
    w1 = (1/c1) * (len(df)) / 2
    return {0:w0, 1:w1}

optimizer = Adam(learning_rate = 0.0001)

# %%
set_seeds(100)

model = Sequential([
    LSTM(64, activation='relu', return_sequences=True, input_shape=(None, len(cols))),
    Dropout(0.3),
    LSTM(32, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # For regression; use 'sigmoid' for binary classification
])
model.compile(loss = "binary_crossentropy", optimizer = optimizer, metrics = ["accuracy"])

X_train = np.expand_dims(train_standardized[cols].values, axis=1)  # Shape becomes (batch_size, 1, features)

model.fit(x=X_train, y=train['dir'], epochs=50, verbose=True,
          validation_split=0.2, shuffle=False, class_weight=cw(train))
# Out:
# Epoch 1/50
# C:\code\trading\v1\pythonProject\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\code\trading\v1\pythonProject\.venv\Lib\site-packages\keras\src\trainers\data_adapters\data_adapter_utils.py:126: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_weight[i] = class_weight.get(int(y[i]), 1.0)
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4959 - loss: 0.6940 - val_accuracy: 0.5032 - val_loss: 0.6932
# Epoch 2/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4879 - loss: 0.6945 - val_accuracy: 0.5126 - val_loss: 0.6929
# Epoch 3/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5047 - loss: 0.6934 - val_accuracy: 0.5184 - val_loss: 0.6930
# Epoch 4/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4904 - loss: 0.6940 - val_accuracy: 0.5214 - val_loss: 0.6929
# Epoch 5/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5125 - loss: 0.6926 - val_accuracy: 0.5266 - val_loss: 0.6928
# Epoch 6/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5040 - loss: 0.6935 - val_accuracy: 0.5278 - val_loss: 0.6926
# Epoch 7/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5099 - loss: 0.6926 - val_accuracy: 0.5336 - val_loss: 0.6925
# Epoch 8/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5166 - loss: 0.6915 - val_accuracy: 0.5260 - val_loss: 0.6924
# Epoch 9/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5150 - loss: 0.6914 - val_accuracy: 0.5301 - val_loss: 0.6924
# Epoch 10/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5385 - loss: 0.6894 - val_accuracy: 0.5272 - val_loss: 0.6923
# Epoch 11/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5347 - loss: 0.6882 - val_accuracy: 0.5260 - val_loss: 0.6925
# Epoch 12/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5453 - loss: 0.6873 - val_accuracy: 0.5155 - val_loss: 0.6928
# Epoch 13/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5405 - loss: 0.6869 - val_accuracy: 0.5260 - val_loss: 0.6926
# Epoch 14/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5566 - loss: 0.6849 - val_accuracy: 0.5196 - val_loss: 0.6927
# Epoch 15/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5418 - loss: 0.6833 - val_accuracy: 0.5266 - val_loss: 0.6928
# Epoch 16/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5546 - loss: 0.6822 - val_accuracy: 0.5155 - val_loss: 0.6930
# Epoch 17/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5526 - loss: 0.6810 - val_accuracy: 0.5138 - val_loss: 0.6931
# Epoch 18/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5723 - loss: 0.6737 - val_accuracy: 0.5108 - val_loss: 0.6934
# Epoch 19/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5657 - loss: 0.6733 - val_accuracy: 0.5167 - val_loss: 0.6941
# Epoch 20/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5744 - loss: 0.6742 - val_accuracy: 0.5138 - val_loss: 0.6943
# Epoch 21/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5637 - loss: 0.6724 - val_accuracy: 0.5126 - val_loss: 0.6947
# Epoch 22/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5850 - loss: 0.6684 - val_accuracy: 0.5138 - val_loss: 0.6955
# Epoch 23/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5803 - loss: 0.6655 - val_accuracy: 0.5108 - val_loss: 0.6960
# Epoch 24/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5738 - loss: 0.6668 - val_accuracy: 0.5120 - val_loss: 0.6971
# Epoch 25/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5888 - loss: 0.6626 - val_accuracy: 0.5161 - val_loss: 0.6975
# Epoch 26/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5881 - loss: 0.6624 - val_accuracy: 0.5138 - val_loss: 0.6980
# Epoch 27/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6002 - loss: 0.6553 - val_accuracy: 0.5161 - val_loss: 0.6985
# Epoch 28/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5948 - loss: 0.6578 - val_accuracy: 0.5114 - val_loss: 0.7002
# Epoch 29/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5957 - loss: 0.6547 - val_accuracy: 0.5149 - val_loss: 0.6991
# Epoch 30/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6101 - loss: 0.6525 - val_accuracy: 0.5126 - val_loss: 0.7015
# Epoch 31/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5935 - loss: 0.6555 - val_accuracy: 0.5079 - val_loss: 0.7015
# Epoch 32/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6042 - loss: 0.6472 - val_accuracy: 0.5114 - val_loss: 0.7027
# Epoch 33/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5914 - loss: 0.6490 - val_accuracy: 0.5138 - val_loss: 0.7067
# Epoch 34/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6153 - loss: 0.6429 - val_accuracy: 0.5091 - val_loss: 0.7067
# Epoch 35/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6029 - loss: 0.6444 - val_accuracy: 0.5126 - val_loss: 0.7098
# Epoch 36/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6134 - loss: 0.6386 - val_accuracy: 0.5050 - val_loss: 0.7103
# Epoch 37/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6222 - loss: 0.6371 - val_accuracy: 0.5097 - val_loss: 0.7131
# Epoch 38/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6201 - loss: 0.6337 - val_accuracy: 0.5038 - val_loss: 0.7132
# Epoch 39/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6333 - loss: 0.6331 - val_accuracy: 0.5032 - val_loss: 0.7145
# Epoch 40/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6238 - loss: 0.6312 - val_accuracy: 0.5026 - val_loss: 0.7162
# Epoch 41/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6387 - loss: 0.6240 - val_accuracy: 0.5003 - val_loss: 0.7164
# Epoch 42/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6270 - loss: 0.6246 - val_accuracy: 0.4962 - val_loss: 0.7162
# Epoch 43/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6464 - loss: 0.6172 - val_accuracy: 0.5032 - val_loss: 0.7216
# Epoch 44/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6232 - loss: 0.6237 - val_accuracy: 0.5009 - val_loss: 0.7177
# Epoch 45/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6438 - loss: 0.6182 - val_accuracy: 0.5015 - val_loss: 0.7205
# Epoch 46/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6388 - loss: 0.6170 - val_accuracy: 0.5061 - val_loss: 0.7269
# Epoch 47/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6499 - loss: 0.6100 - val_accuracy: 0.5079 - val_loss: 0.7249
# Epoch 48/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6483 - loss: 0.6058 - val_accuracy: 0.5050 - val_loss: 0.7257
# Epoch 49/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6590 - loss: 0.6028 - val_accuracy: 0.4950 - val_loss: 0.7301
# Epoch 50/50
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6569 - loss: 0.6064 - val_accuracy: 0.4933 - val_loss: 0.7302

# %%
X_eval = np.expand_dims(train_standardized[cols].values, axis=1)

model.evaluate(X_eval, train['dir'])
# Out:
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.6934 - loss: 0.5786
# [0.6226682662963867, 0.6439606547355652]

# %%
predict = model.predict(X_eval)
predict
# Out:
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# array([[0.5625707 ],
#        [0.4137416 ],
#        [0.26600865],
#        ...,
#        [0.5222263 ],
#        [0.2353961 ],
#        [0.2576677 ]], dtype=float32)

# %%
plt.hist(predict, bins=50)
plt.show()

# %%
test
# Out:
#                             gold_price  gold_volume    snp_price   snp_volume  \
# Datetime
# 2024-01-17 00:00:00+00:00  2031.599976       2532.0  4765.180176  336315998.0
# 2024-01-17 01:00:00+00:00  2033.400024       4852.0  4765.180176  336315998.0
# 2024-01-17 02:00:00+00:00  2032.000000       5865.0  4765.180176  336315998.0
# 2024-01-17 03:00:00+00:00  2027.199951       4409.0  4765.180176  336315998.0
# 2024-01-17 04:00:00+00:00  2028.500000       2729.0  4765.180176  336315998.0
# ...                                ...          ...          ...          ...
# 2024-08-19 18:00:00+00:00  2542.800049       5353.0  5588.919922  173170955.0
# 2024-08-19 19:00:00+00:00  2543.899902       3701.0  5594.100098  215252315.0
# 2024-08-19 20:00:00+00:00  2542.600098       1749.0  5607.520020  242772673.0
# 2024-08-19 21:00:00+00:00  2542.600098       1749.0  5607.520020  242772673.0
# 2024-08-19 22:00:00+00:00  2542.500000          0.0  5607.520020  242772673.0
#
#                            snp_volatility  snp_returns      Open      High  \
# Datetime
# 2024-01-17 00:00:00+00:00        0.002521     0.001760  1.088139  1.088139
# 2024-01-17 01:00:00+00:00        0.002521     0.001760  1.088139  1.088376
# 2024-01-17 02:00:00+00:00        0.002521     0.001760  1.088021  1.088732
# 2024-01-17 03:00:00+00:00        0.002521     0.001760  1.087666  1.087784
# 2024-01-17 04:00:00+00:00        0.002521     0.001760  1.086838  1.087429
# ...                                   ...          ...       ...       ...
# 2024-08-19 18:00:00+00:00        0.001423     0.001019  1.108156  1.108770
# 2024-08-19 19:00:00+00:00        0.001372     0.000926  1.108402  1.108893
# 2024-08-19 20:00:00+00:00        0.002894     0.002396  1.108647  1.108893
# 2024-08-19 21:00:00+00:00        0.002894     0.002396  1.108525  1.109139
# 2024-08-19 22:00:00+00:00        0.002894     0.002396  1.109016  1.109016
#
#                                 Low     Close  ...  returns_lag_15  \
# Datetime                                       ...
# 2024-01-17 00:00:00+00:00  1.087548  1.088139  ...       -0.001635
# 2024-01-17 01:00:00+00:00  1.087666  1.088021  ...       -0.000544
# 2024-01-17 02:00:00+00:00  1.087666  1.087784  ...        0.000980
# 2024-01-17 03:00:00+00:00  1.086838  1.086957  ...       -0.000545
# 2024-01-17 04:00:00+00:00  1.086838  1.087311  ...       -0.001197
# ...                             ...       ...  ...             ...
# 2024-08-19 18:00:00+00:00  1.108033  1.108525  ...        0.000773
# 2024-08-19 19:00:00+00:00  1.108279  1.108647  ...        0.000000
# 2024-08-19 20:00:00+00:00  1.108525  1.108893  ...        0.000773
# 2024-08-19 21:00:00+00:00  1.108279  1.108647  ...       -0.000552
# 2024-08-19 22:00:00+00:00  1.108647  1.108770  ...        0.000110
#
#                            returns_lag_16  returns_lag_17  returns_lag_18  \
# Datetime
# 2024-01-17 00:00:00+00:00       -0.001200       -0.000109        0.000328
# 2024-01-17 01:00:00+00:00       -0.001635       -0.001200       -0.000109
# 2024-01-17 02:00:00+00:00       -0.000544       -0.001635       -0.001200
# 2024-01-17 03:00:00+00:00        0.000980       -0.000544       -0.001635
# 2024-01-17 04:00:00+00:00       -0.000545        0.000980       -0.000544
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00       -0.000110        0.000000        0.000662
# 2024-08-19 19:00:00+00:00        0.000773       -0.000110        0.000000
# 2024-08-19 20:00:00+00:00        0.000000        0.000773       -0.000110
# 2024-08-19 21:00:00+00:00        0.000773        0.000000        0.000773
# 2024-08-19 22:00:00+00:00       -0.000552        0.000773        0.000000
#
#                            returns_lag_19  returns_lag_20  returns_lag_21  \
# Datetime
# 2024-01-17 00:00:00+00:00       -0.000218       -0.000109       -0.000437
# 2024-01-17 01:00:00+00:00        0.000328       -0.000218       -0.000109
# 2024-01-17 02:00:00+00:00       -0.000109        0.000328       -0.000218
# 2024-01-17 03:00:00+00:00       -0.001200       -0.000109        0.000328
# 2024-01-17 04:00:00+00:00       -0.001635       -0.001200       -0.000109
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00       -0.000331        0.000110        0.000221
# 2024-08-19 19:00:00+00:00        0.000662       -0.000331        0.000110
# 2024-08-19 20:00:00+00:00        0.000000        0.000662       -0.000331
# 2024-08-19 21:00:00+00:00       -0.000110        0.000000        0.000662
# 2024-08-19 22:00:00+00:00        0.000773       -0.000110        0.000000
#
#                            returns_lag_22  returns_lag_23  returns_lag_24
# Datetime
# 2024-01-17 00:00:00+00:00       -0.000328        0.000656       -0.002296
# 2024-01-17 01:00:00+00:00       -0.000437       -0.000328        0.000656
# 2024-01-17 02:00:00+00:00       -0.000109       -0.000437       -0.000328
# 2024-01-17 03:00:00+00:00       -0.000218       -0.000109       -0.000437
# 2024-01-17 04:00:00+00:00        0.000328       -0.000218       -0.000109
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00        0.000331        0.000771        0.000771
# 2024-08-19 19:00:00+00:00        0.000221        0.000331        0.000771
# 2024-08-19 20:00:00+00:00        0.000110        0.000221        0.000331
# 2024-08-19 21:00:00+00:00       -0.000331        0.000110        0.000221
# 2024-08-19 22:00:00+00:00        0.000662       -0.000331        0.000110
#
# [3663 rows x 277 columns]

# %%
test_standardized = (test-mu) / std
test_standardized
# Out:
#                            gold_price  gold_volume  snp_price  snp_volume  \
# Datetime
# 2024-01-17 00:00:00+00:00    1.105603    -0.576364   1.956434    0.278652
# 2024-01-17 01:00:00+00:00    1.120895    -0.305337   1.956434    0.278652
# 2024-01-17 02:00:00+00:00    1.109001    -0.186997   1.956434    0.278652
# 2024-01-17 03:00:00+00:00    1.068223    -0.357089   1.956434    0.278652
# 2024-01-17 04:00:00+00:00    1.079267    -0.553350   1.956434    0.278652
# ...                               ...          ...        ...         ...
# 2024-08-19 18:00:00+00:00    5.448477    -0.246809   4.765560   -1.096674
# 2024-08-19 19:00:00+00:00    5.457820    -0.439799   4.783225   -0.741925
# 2024-08-19 20:00:00+00:00    5.446778    -0.667835   4.828990   -0.509926
# 2024-08-19 21:00:00+00:00    5.446778    -0.667835   4.828990   -0.509926
# 2024-08-19 22:00:00+00:00    5.445927    -0.872157   4.828990   -0.509926
#
#                            snp_volatility  snp_returns      Open      High  \
# Datetime
# 2024-01-17 00:00:00+00:00       -0.426632     0.594675  0.617481  0.599444
# 2024-01-17 01:00:00+00:00       -0.426632     0.594675  0.617481  0.605937
# 2024-01-17 02:00:00+00:00       -0.426632     0.594675  0.614249  0.615680
# 2024-01-17 00:00:00+00:00       -0.290586        0.554476       -1.982957
# 2024-01-17 01:00:00+00:00       -0.384292       -0.290667        0.554202
# 2024-01-17 02:00:00+00:00       -0.102680       -0.384361       -0.291074
# 2024-01-17 03:00:00+00:00       -0.196428       -0.102783       -0.384783
# 2024-01-17 04:00:00+00:00        0.272782       -0.196520       -0.103161
# ...                                   ...             ...             ...
# 2024-08-19 18:00:00+00:00        0.275559        0.654006        0.653235
# 2024-08-19 19:00:00+00:00        0.180821        0.275410        0.653748
# 2024-08-19 20:00:00+00:00        0.085961        0.180684        0.275092
# 2024-08-19 21:00:00+00:00       -0.293108        0.085835        0.180351
# 2024-08-19 22:00:00+00:00        0.560075       -0.293188        0.085487
#
# [3663 rows x 277 columns]

# %%
test_standardized.describe()
# Out:
#         gold_price  gold_volume    snp_price   snp_volume  snp_volatility  \
# count  3663.000000  3663.000000  3663.000000  3663.000000     3663.000000
# mean      3.200951     0.120640     3.543728     0.000627       -0.257474
# std       1.284181     1.093883     0.728563     0.664022        0.797679
# min       0.836298    -0.872157     1.812557    -2.556520       -1.214839
# 25%       2.210436    -0.537462     2.993922    -0.252510       -0.768557
# 50%       3.698414    -0.249964     3.504260     0.002684       -0.426632
# 75%       4.078160     0.320595     4.218084     0.221289       -0.063816
# max       5.479909    12.299163     5.033739     5.022257        7.468390
#
#        snp_returns         Open         High          Low        Close  ...  \
# count  3663.000000  3663.000000  3663.000000  3663.000000  3663.000000  ...
# mean      0.009429     0.450739     0.444085     0.456196     0.450728  ...
# std       0.909800     0.225644     0.226104     0.225226     0.226020  ...
# min     -11.958683    -0.114042    -0.128773    -0.119296    -0.117427  ...
# 25%      -0.349484     0.281881     0.281573     0.287102     0.284760  ...
# 50%       0.047264     0.475919     0.466975     0.483460     0.475656  ...
# 75%       0.449283     0.602941     0.596200     0.605115     0.604304  ...
# max       6.029409     1.187472     1.175042     1.191971     1.183908  ...
#
#        returns_lag_15  returns_lag_16  returns_lag_17  returns_lag_18  \
# count     3663.000000     3663.000000     3663.000000     3663.000000
# mean        -0.005646       -0.006175       -0.006082       -0.006164
# std          0.608214        0.608466        0.608417        0.608338
# min         -6.198638       -6.198990       -6.199004       -6.199006
# 25%         -0.285327       -0.285590       -0.285566       -0.285544
# 50%         -0.008608       -0.008830       -0.008841       -0.008818
# 75%          0.269055        0.268839        0.268828        0.268852
# max          5.096859        5.096744        5.096736        5.096780
#
#        returns_lag_19  returns_lag_20  returns_lag_21  returns_lag_22  \
# count     3663.000000     3663.000000     3663.000000     3663.000000
# mean        -0.006257       -0.006535       -0.006494       -0.006534
# std          0.608347        0.608242        0.608209        0.608217
# min         -6.199053       -6.199035       -6.198276       -6.198134
# 25%         -0.285586       -0.285653       -0.285543       -0.285584
# 50%         -0.008860       -0.008931       -0.008813       -0.008775
# 75%          0.268810        0.268735        0.268824        0.268857
# max          5.096741        5.096596        5.096186        5.096137
#
#        returns_lag_23  returns_lag_24
# count     3663.000000     3663.000000
# mean        -0.006649       -0.007473
# std          0.608142        0.609096
# min         -6.197501       -6.198844
# 25%         -0.285665       -0.286072
# 50%         -0.008890       -0.009253
# 75%          0.268709        0.268390
# max          5.095407        5.095852
#
# [8 rows x 277 columns]

# %%
X_test = np.expand_dims(test_standardized[cols].values, axis=1)
model.evaluate(X_test, test['dir'])
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.5254 - loss: 0.7896
# [0.8611105680465698, 0.5350805521011353]

# %%
pred = model.predict(X_test)
pred
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.47772962],
#        [0.28556934],
#        [0.3351918 ],
#        ...,
#        [0.03679119],
#        [0.02289583],
#        [0.02266233]], dtype=float32)

# %%
test['probability'] = model.predict(X_test)
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step

# %%
plt.hist(test['probability'], bins=100)
plt.show()

# %%
plt.hist(pred, bins=100)
plt.show()

# %%
threshold = 0.56

# %%
test['position'] = np.where(test.probability < (1-threshold), -1, np.nan)
test['position'] = np.where(test.probability > threshold, 1, test.position)
test['position'] = np.where(np.logical_and(test.probability>=1-threshold, test.probability<=threshold), 0, test.position)

# %%
#test.index = test.index.tz_localize('utc')
#test['NYTime'] = test.index.tz_convert("America/New_York")
#test['hour'] = test.NYTime.dt.hour

# %%
#test['position'] = np.where(~test.hour.between(2,12), 0, test.position)

# %%
test.position.value_counts(dropna=False)
# Out:
# position
# -1.0    2681
#  1.0     536
#  0.0     446
# Name: count, dtype: int64

# %%
test['position'] = test.position.ffill()

# %%
test.position.value_counts(dropna=False)
# Out:
# position
# -1.0    2681
#  1.0     536
#  0.0     446
# Name: count, dtype: int64

# %%
test['strategy'] = test['position'] * test['returns']

# %%
test['creturns'] = test['returns'].cumsum().apply(np.exp)
test['cstrategy'] = test['strategy'].cumsum().apply(np.exp)

# %%
test[['creturns', 'cstrategy']].plot()
plt.show()

# %%
ptc = 0.000059

# %%
test['trades'] = test.position.diff().abs()
test.trades.value_counts()
# Out:
# trades
# 0.0    2619
# 1.0     671
# 2.0     372
# Name: count, dtype: int64

# %%
test['strategy_net'] = test.strategy - test.trades * ptc

# %%
test['cstrategy_net'] = test['strategy_net'].cumsum().apply(np.exp)

# %%
test[['creturns', 'cstrategy', 'cstrategy_net']].plot(figsize=(12, 8))
plt.show()

# %%
#model.save('DNN_modelv3.keras')

# %%
import pickle

# %%
params = {'mu': mu, 'std': std}

# %%
#pickle.dump(params, open('paramsv3.pkl', 'wb'))

# %%
test[['strategy_net']].mean() * 252
# Out:
# strategy_net   -0.008888
# dtype: float64

# %%
train_standardized[cols].values
# Out:
# array([[-1.40869249, -1.3336066 , -1.35026129, ..., -0.6112035 ,
#          1.53918064,  1.10718398],
#        [-1.39000272, -1.40836118, -1.3332723 , ..., -1.3841345 ,
#         -0.61124499,  1.53906263],
#        [-1.40699285, -1.38967202, -1.40802426, ...,  0.50671724,
#         -1.38408272, -0.61170343],
#        ...,
#        [ 1.10754678,  1.11629131,  1.08001312, ..., -0.38526066,
#         -0.10297374, -0.10343494],
#        [ 1.10669644,  1.10779652,  1.11653986, ..., -1.98240581,
#         -0.38532941, -0.10335172],
#        [ 1.10669644,  1.10694621,  1.10804537, ...,  0.55465776,
#         -1.98228183, -0.38575209]])
